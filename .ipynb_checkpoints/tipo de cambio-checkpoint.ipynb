# %%
##Procredit
from lxml import html
import requests
page = requests.get('https://www.procredit.com.ni/Pages/BancaPersonas/ServiciosFinancieros/MesaCambio.aspx')
tree = html.fromstring(page.text)
tree.xpath('//span/text()')
tree.xpath('//span/text()')
row = tree.xpath('//span/text()')

row[8]
row[10]
row[12]
# Out:
# '29.0136'

# %%
row[8]
# Out:
# '28.8700'

# %%
##Banpro
from lxml import html
import requests
page1 = requests.get('https://www.banpro.com.ni/banproenlinea/ad_olvidoclave.asp?SourcePage=')
tree1 = html.fromstring(page1.text)

# %%
tree1.xpath('//span/text()')
# Out:
# [u'\xa0Tipo Cambio Ventanilla\xa0', u'\xa028.9100\xa0\xa0\xa0', u'\xa029.3900']

# %%
row1 = tree1.xpath('//span/text()')

# %%
row1[1][1:8]
# Out:
# u'28.9100'

# %%
row1[2][1:8]
# Out:
# u'29.3900'

# %%
##Lafise
from lxml import html
import requests
page2 = requests.get('https://www.lafise.com/blb/')
tree2 = html.fromstring(page2.text)

# %%
tree2.xpath('//span/text()')
# Out:
# ['\r\n    \r\n    \r\n    ',
#  '\r\n        ',
#  '\r\n        ',
#  '\r\n    ',
#  '\r\n    ',
#  '\r\n',
#  u'LAFISE M\xf3vil',
#  'LAFISE Plus',
#  'MONIBYTE',
#  'Tasas de Cambio',
#  u'Suscripci\xf3n a boletines',
#  'Suscripcion Boletin',
#  u'\xd7',
#  'Acerca de LAFISE',
#  'Monibyte']

# %%
tree2
# Out:
# <Element html at 0x4800688>

# %%
##Lafise
from lxml import html
import requests
headers = {'User-agent': 'Mozilla/5.0'}
page2 = requests.get('https://www.lafise.com/blb/',headers=headers)
soup = BeautifulSoup(page2.content)

# %%
soup.find('a')
# Out:
# <a href="https://www.lafise.com/blb/register?returnurl=https%3a%2f%2fwww.lafise.com%2fblb%2f" id="dnn_userLogin_registerLink">Register</a>

# %%
print soup.prettify()
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html lang="en-US">
#  <head id="Head">
#   <!--*********************************************-->
#   <!-- DNN Platform - http://www.dnnsoftware.com   -->
#   <!-- Copyright (c) 2002-2015, by DNN Corporation -->
#   <!--*********************************************-->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Banco LAFISE Nicaragua &gt; Home
#   </title>
#   <meta content=",DotNetNuke,DNN" id="MetaKeywords" name="KEYWORDS"/>
#   <meta content="DotNetNuke " id="MetaGenerator" name="GENERATOR"/>
#   <meta content="INDEX, FOLLOW" id="MetaRobots" name="ROBOTS"/>
#   <link href="/Portals/_default/default.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/DesktopModules/HTML/module.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/Resources/Search/SearchSkinObjectPreview.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/Portals/_default/Containers/TabsPro/container.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/Portals/_default/Containers/Cavalier/container.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/DesktopModules/EasyDnnGallery/css/nivo-slider.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/DesktopModules/EasyDNNNews/static/rateit/css/rateit.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/DesktopModules/EasyDNNGallery/css/prettyPhoto.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/DesktopModules/EasyDNNGallery/css/admin.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/DesktopModules/EasyDnnGallery/css/themes/default/default.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/DesktopModules/EasyDnnGallery/css/jquery.qtip.css?cdv=100" media="all" rel="stylesheet" type="text/css"/>
#   <script src="/DesktopModules/EasyDNNGallery/js/eds1.8.2.js?cdv=100" type="text/javascript">
#   </script>
#   <script src="/Resources/libraries/jQuery/01_09_01/jquery.js?cdv=100" type="text/javascript">
#   </script>
#   <script src="/Resources/libraries/jQuery-Migrate/01_02_01/jquery-migrate.js?cdv=100" type="text/javascript">
#   </script>
#   <script src="/Resources/libraries/jQuery-UI/01_10_03/jquery-ui.js?cdv=100" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
#     var analytics_page_startTime = (new Date()).getTime();
# //]]>
#   </script>
#   <link href="/Portals/1/favicon.ico?ver=2015-11-10-144824-000" rel="SHORTCUT ICON" type="image/x-icon"/>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#             _gaq.push(['_setAccount', 'UA-54448766-3']);
#             _gaq.push(['_setDomainName', 'none']);
#             _gaq.push(['_setAllowHash', true]);
#
#
#             _gaq.push(['_trackPageview']);
#
#             (function() {
#             var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#             ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#             var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#             })();
#   </script>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0" name="viewport"/>
#   <script data-init-json='{"instanceGlobal": "EasyDnnSolutions1_1_instance","google": {"maps": {"api": {"key": "","libraries": ["geometry", "places"]}}}}' data-minor-version="0" id="eds_js1_1" src="/DesktopModules/EasyDNNnews/static/EasyDnnSolutions/EasyDnnSolutions_1.1.js" type="text/javascript">
#   </script>
#  </head>
#  <body id="Body">
#   <form action="/blb/" enctype="multipart/form-data" id="Form" method="post">
#    <div class="aspNetHidden">
#     <input id="StylesheetManager_TSSM" name="StylesheetManager_TSSM" type="hidden" value=""/>
#     <input id="ScriptManager_TSM" name="ScriptManager_TSM" type="hidden" value=""/>
#     <input id="__EVENTTARGET" name="__EVENTTARGET" type="hidden" value=""/>
#     <input id="__EVENTARGUMENT" name="__EVENTARGUMENT" type="hidden" value=""/>
#     <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
#    </div>
#    <script type="text/javascript">
#     //<![CDATA[
# var theForm = document.forms['Form'];
# if (!theForm) {
#     theForm = document.Form;
# }
# function __doPostBack(eventTarget, eventArgument) {
#     if (!theForm.onsubmit || (theForm.onsubmit() != false)) {
#         theForm.__EVENTTARGET.value = eventTarget;
#         theForm.__EVENTARGUMENT.value = eventArgument;
#         theForm.submit();
#     }
# }
# //]]>
#    </script>
#    <script src="/WebResource.axd?d=0foDfmi9TVzIVtI5U7kvmGnrQdQmwnv7wuZoJ1jRRDOSzx-TpaXpqOpeV-KrGFiJxJqgSEXCPi5w0hm50&amp;t=635792811671809273" type="text/javascript">
#    </script>
#    <script src="/Telerik.Web.UI.WebResource.axd?_TSM_HiddenField_=ScriptManager_TSM&amp;compress=1&amp;_TSM_CombinedScripts_=%3b%3bSystem.Web.Extensions%2c+Version%3d4.0.0.0%2c+Culture%3dneutral%2c+PublicKeyToken%3d31bf3856ad364e35%3aen-US%3a93a6b8ed-f453-4cc5-9080-8017894b33b0%3aea597d4b%3ab25378d2" type="text/javascript">
#    </script>
#    <div class="aspNetHidden">
#     <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="CA0B0334"/>
#     <input id="__VIEWSTATEENCRYPTED" name="__VIEWSTATEENCRYPTED" type="hidden" value=""/>
#     <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="1ZJXry7WAPsREs3eHahEzKje0je1D8+GT9av+25Ny0U387YINPOGQizixQxiKHLUOK9AQu08JA5S4AQa7CFgSyItQM0nEowO3F4I1+8T0oWbI+Ppl2v6ja0al5GJqvdNZJBn6C2/DXkKwt3xBJDqFY52uJ8XZZNjimBFLeHu+GJLlbG3gJeYQ7ruJeA="/>
#    </div>
#    <script src="/App/Base/js/angular.min.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/App/Base/js/ui-bootstrap-tpls.min.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/App/FrontEnd/SuscripcionBoletin/SuscripcionBoletinModule.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/App/FrontEnd/TasaCambio/TasaCambioModule.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/App/FrontEnd/SuscripcionBoletin/SuscripcionBoletinFactory.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/App/FrontEnd/TasaCambio/TasaCambioFactory.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/App/FrontEnd/SuscripcionBoletin/SuscripcionBoletinController.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/App/FrontEnd/TasaCambio/TasaCambioController.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/App/Base/js/VentanaCargando.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/js/dnn.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/js/dnn.modalpopup.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/Resources/Shared/Scripts/jquery/jquery.hoverIntent.min.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/js/dnn.servicesframework.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/Resources/Shared/Scripts/jquery/jquery.fileupload.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/DesktopModules/EasyDNNNews/js/jquery.rateit.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/DesktopModules/EasyDnnGallery/js/jquery.nivo.slider.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/DesktopModules/EasyDNNGallery/js/jquery.prettyPhoto.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/Resources/Search/SearchSkinObjectPreview.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/js/dnncore.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/DesktopModules/DNNCorp/EvoqContentLibrary/ClientScripts/dnn.analytics.Injected.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/Resources/Shared/Scripts/jquery/jquery.iframe-transport.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/Resources/Shared/Scripts/dnn.jquery.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/DesktopModules/EasyDNNNews/js/jquery.cookie.js?cdv=100" type="text/javascript">
#    </script>
#    <script src="/DesktopModules/EasyDnnGallery/static/qtip2/jquery.qtip.js?cdv=100" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     //<![CDATA[
# Sys.WebForms.PageRequestManager._initialize('ScriptManager', 'Form', [], [], [], 90, '');
# //]]>
#    </script>
#    <meta content="telephone=no" name="format-detection"/>
#    <header>
#     <div class="row loginAdmin clearfix">
#      <div class="container clearfix">
#       <div class="admin">
#        <div class="userProperties">
#         <ul>
#          <li class="userRegister">
#           <a href="https://www.lafise.com/blb/register?returnurl=https%3a%2f%2fwww.lafise.com%2fblb%2f" id="dnn_userLogin_registerLink">
#            Register
#           </a>
#          </li>
#          <li class="userLogin">
#           <a href="https://www.lafise.com/blb/login?returnurl=%2fblb%2f" id="dnn_userLogin_loginLink">
#            Login
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="row header clearfix">
#      <div class="container clearfix">
#       <div class="grid_3 logo" id="logo">
#        <a href="/">
#        </a>
#        <a href="https://www.lafise.com/blb/" id="dnn_dnnLOGO_hypLogo" title="Banco LAFISE Nicaragua">
#         <img alt="Banco LAFISE Nicaragua" id="dnn_dnnLOGO_imgLogo" src="/Portals/1/logo.png?ver=2016-05-13-191714-000"/>
#        </a>
#       </div>
#       <div class="grid_9">
#        <div class="grid_2 alpha omega redes" id="dnn_redes">
#         <div class="DnnModule DnnModule-DNN_HTML DnnModule-651 DnnVersionableControl">
#          <a name="651">
#          </a>
#          <div id="dnn_ctr651_ContentPane">
#           <!-- Start_Module_651 -->
#           <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr651_ModuleContent">
#            <div id="dnn_ctr651_HtmlModule_lblContent">
#             <a class="fb" href="https://www.facebook.com/BancoLafiseNicaragua">
#              facebook
#             </a>
#             <a class="tw" href="https://twitter.com/LAFISENicaragua">
#              twitter
#             </a>
#             <a class="yt" href="https://www.youtube.com/channel/UCJFIPRRerp5gdo1b7dtFUSQ">
#              youtube
#             </a>
#             <a class="linked" href="https://www.linkedin.com/company/lafise">
#              LinkedIn
#             </a>
#             <br/>
#            </div>
#           </div>
#           <!-- End_Module_651 -->
#          </div>
#         </div>
#        </div>
#        <div class="grid_6 alpha omega transversal" id="dnn_transversal">
#         <div class="DnnModule DnnModule-DNN_HTML DnnModule-652 DnnVersionableControl">
#          <a name="652">
#          </a>
#          <div id="dnn_ctr652_ContentPane">
#           <!-- Start_Module_652 -->
#           <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr652_ModuleContent">
#            <div id="dnn_ctr652_HtmlModule_lblContent">
#             <div class="headerTools">
#              <a href="/blb/preguntas-frecuentes">
#               Preguntas frecuentes
#              </a>
#              <a href="/blb/contactenos">
#               Contáctanos
#              </a>
#              <a href="/blb/encuentranos">
#               Encuéntranos
#              </a>
#             </div>
#            </div>
#           </div>
#           <!-- End_Module_652 -->
#          </div>
#         </div>
#        </div>
#        <div class="grid_1 alpha omega search" id="search">
#         <a class="searchBtn visible" href="javascript:void(0);">
#         </a>
#         <span id="dnn_dnnSearch_ClassicSearch">
#          <span class="searchInputContainer" data-moreresults="Ver más resultados" data-noresult="No se encontraron resultados">
#           <input autocomplete="off" class="NormalTextBox" id="dnn_dnnSearch_txtSearch" maxlength="255" name="dnn$dnnSearch$txtSearch" placeholder="Buscar" size="20" type="text"/>
#           <a class="dnnSearchBoxClearText">
#           </a>
#          </span>
#          <a class="SearchButton" href="javascript:__doPostBack('dnn$dnnSearch$cmdSearch','')" id="dnn_dnnSearch_cmdSearch">
#          </a>
#         </span>
#         <script type="text/javascript">
#          $(function() {
#         if (typeof dnn != "undefined" && typeof dnn.searchSkinObject != "undefined") {
#             var searchSkinObject = new dnn.searchSkinObject({
#                 delayTriggerAutoSearch : 400,
#                 minCharRequiredTriggerAutoSearch : 2,
#                 searchType: 'S',
#                 enableWildSearch: true,
#                 cultureCode: 'en-US',
#                 portalId: -1
#                 }
#             );
#             searchSkinObject.init();
#
#
#             // attach classic search
#             var siteBtn = $('#dnn_dnnSearch_SiteRadioButton');
#             var webBtn = $('#dnn_dnnSearch_WebRadioButton');
#             var clickHandler = function() {
#                 if (siteBtn.is(':checked')) searchSkinObject.settings.searchType = 'S';
#                 else searchSkinObject.settings.searchType = 'W';
#             };
#             siteBtn.on('change', clickHandler);
#             webBtn.on('change', clickHandler);
#
#
#         }
#     });
#         </script>
#        </div>
#        <div class="grid_3 omega BancaNet">
#         <div class="" id="dnn_BancaNet">
#          <div class="DnnModule DnnModule-DNN_HTML DnnModule-654 DnnVersionableControl">
#           <a name="654">
#           </a>
#           <div id="dnn_ctr654_ContentPane">
#            <!-- Start_Module_654 -->
#            <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr654_ModuleContent">
#             <div id="dnn_ctr654_HtmlModule_lblContent">
#              <a class="bancaBtn" href="javascript:void(0);">
#               BancaNet
#              </a>
#             </div>
#            </div>
#            <!-- End_Module_654 -->
#           </div>
#          </div>
#         </div>
#         <div class="BancaNetList" id="dnn_BancaNetList">
#          <div class="DnnModule DnnModule-DNN_HTML DnnModule-655 DnnVersionableControl">
#           <a name="655">
#           </a>
#           <div id="dnn_ctr655_ContentPane">
#            <!-- Start_Module_655 -->
#            <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr655_ModuleContent">
#             <div id="dnn_ctr655_HtmlModule_lblContent">
#              <ul class="list">
#               <li>
#                <a href="https://secure.bancolafise.com.ni/">
#                 Nicaragua
#                </a>
#               </li>
#               <li>
#                <a href="https://secure.bancanetregional.com/ebanking/AccessMobile.do">
#                 Regional
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <!-- End_Module_655 -->
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="grid_12 alpha omega menu" id="menu">
#         <a class="responsiveMenuButton" href="javascript:void(0);">
#          Menú
#         </a>
#         <ul id="dnn_pnav">
#          <li class="">
#           <a href="https://www.lafise.com/blb/banca-personal" target="">
#            Banca personal
#           </a>
#           <ul>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-personal/cuenta-de-ahorros" target="">
#              Cuentas de ahorro
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-personal/cuenta-corriente" target="">
#              Cuenta corriente
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-personal/prestamos" target="">
#              Préstamos
#             </a>
#             <ul>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/prestamos/prestamos-personales" target="">
#                Préstamos personales
#               </a>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/prestamos/prestamos-de-vehiculos" target="">
#                Préstamos de vehículos
#               </a>
#               <ul>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/prestamos/prestamos-de-vehiculos/solicitud-prestamos-de-vehiculos" target="">
#                  Solicitud préstamos de vehÍculos
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://ws.lafws.com/Cotizador/Vehicle" target="_new">
#                  Calculadora
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/prestamos/prestamos-de-vivienda" target="">
#                Préstamos de vivienda
#               </a>
#               <ul>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/prestamos/solicitud-prestamos-vivienda" target="">
#                  Solicitud préstamos vivienda
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/prestamos/solicitud-prestamos-educativo" target="">
#                Préstamos educativo
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-personal/tarjetas" target="">
#              Tarjetas
#             </a>
#             <ul>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/tarjetas/beneficios/puntos-lafise" target="">
#                Beneficios
#               </a>
#               <ul>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/beneficios/puntos-lafise" target="">
#                  Puntos LAFISE
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/beneficios/lafise-plus" target="">
#                  LAFISE Plus
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/beneficios/extrafinanciamientos" target="">
#                  Extrafinanciamientos
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/beneficios/plan-de-compras-en-cuotas" target="">
#                  Plan de Compras en Cuotas
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/beneficios/tasa-0-0-interes" target="">
#                  Tasa 0 (0% interés)
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito" target="">
#                Tarjetas crédito
#               </a>
#               <ul>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-de-credito/tarjeta-infinite-visa" target="">
#                  Tarjeta Infinite Visa
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito/tarjeta-signature-visa" target="">
#                  Tarjeta Signature Visa
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito/tarjeta-platinum-visa" target="">
#                  Tarjeta Platinum Visa
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito/tarjeta-dorada-visa" target="">
#                  Tarjeta Dorada Visa
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito/tarjeta-clasica-visa" target="">
#                  Tarjeta Clásica Visa
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito/tarjeta-fundacion-zamora-teran-visa" target="">
#                  Tarjeta Fundación Zamora Teran Visa
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-crédito/tarjeta-dtodo-visa" target="">
#                  Tarjeta DTodo Visa
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito/tarjeta-business-visa" target="">
#                  Tarjeta Business Visa
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito/tarjeta-platinum-mastercard" target="">
#                  Tarjeta Platinum  Mastercard
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito/tarjeta-dorada-mastercard" target="">
#                  Tarjeta Dorada Mastercard
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito/tarjeta-clasica-mastercard" target="">
#                  Tarjeta Clásica Mastercard
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-credito/solicitud-tarjeta-credito" target="">
#                  Solicitud Tarjeta Crédito
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-debito" target="">
#                Tarjetas débito
#               </a>
#               <ul>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-debito/solicitud-tarjeta-debito" target="">
#                  Solicitud tarjeta débito
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-prepago" target="">
#                Tarjetas prepago
#               </a>
#               <ul>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-prepago/tarjeta-nomina-visa" target="">
#                  Tarjeta Nomina Visa
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/tarjetas-prepago/tarjeta-joven-visa" target="">
#                  Tarjeta Joven Visa
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/tarjetas/servicios" target="">
#                Servicios
#               </a>
#               <ul>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/servicios/estado-de-cuenta-por-e-mail" target="">
#                  Estado de cuenta por E-mail
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/servicios/consultas-retiros-y-pagos-de-tarjeta" target="">
#                  Consultas, retiros y pagos de tarjeta
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/servicios/telepagos-1800-8472" target="">
#                  Telepagos 1800-8472
#                 </a>
#                </li>
#                <li class="">
#                 <a href="https://www.lafise.com/blb/banca-personal/tarjetas/servicios/gestiones-en-linea" target="">
#                  Gestiones en línea
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/tarjetas/seguros-al-viajar" target="">
#                Seguros al viajar
#               </a>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/tarjetas/seguros-prf-vida-y-asistencia" target="">
#                Seguros PRF, vida y asistencia
#               </a>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/tarjetas/contratos-y-reglamentos" target="">
#                Contratos y reglamentos
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-personal/servicios-bancarios" target="">
#              Servicios bancarios
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-personal/canales-electronicos/bancanet" target="">
#              Canales Alternos
#             </a>
#             <ul>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/canales-electronicos/bancanet" target="">
#                Banc@Net
#               </a>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/canales-alternos/red-atm" target="">
#                Red ATM
#               </a>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/canales-alternos/envío-veloz" target="">
#                Envío Veloz
#               </a>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/canales-alternos/transferencias-interbancarias-vía-ach" target="">
#                Transferencias interbancarias vía ACH
#               </a>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/canales-electronicos/lafise-movil" target="">
#                LAFISE Móvil
#               </a>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/canales-electronicos/paganet" target="">
#                Pag@Net
#               </a>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/canales-electronicos/lafiseid" target="">
#                LAFISEid
#               </a>
#              </li>
#              <li class="">
#               <a href="https://www.lafise.com/blb/banca-personal/canales-alternos/servired" target="">
#                ServiRED
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-personal/transferencias" target="">
#              Transferencias
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/Portals/1/Pdf/guia_calculo_interes.pdf" target="_new">
#              Guía de Cálculo de Interés y Mantenimiento de Valor
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="">
#           <a href="https://www.lafise.com/blb/banca-corporativa" target="">
#            Banca corporativa
#           </a>
#           <ul>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/cuentas" target="">
#              Cuentas
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/financiamiento" target="">
#              Financiamiento
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/monibyte" target="">
#              Monibyte
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/custodia-y-transporte-de-valores" target="">
#              Custodia y transporte de valores
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/inversion/certificados-de-deposito" target="">
#              Inversión
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/pagos" target="">
#              Pagos
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/servicios-fiduciarios" target="">
#              Servicios fiduciarios
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/servicios-internacionales" target="">
#              Servicios internacionales
#             </a>
#            </li>
#            <li class="">
#             <a href="http://www.lafise.com/blb/banca-personal/canales-electronicos/bancanet" target="">
#              Canales Alternos
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/servicio-de-afiliacion-a-pos" target="">
#              Servicio de afiliación a POS
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/ecocreditos" target="">
#              ECOCréditos
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="">
#           <a href="https://www.lafise.com/blb/banca-empresarial" target="">
#            Banca empresarial
#           </a>
#           <ul>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/cuentas" target="">
#              Cuentas
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/financiamiento" target="">
#              Financiamiento
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/monibyte" target="">
#              Monibyte
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/inversion" target="">
#              Inversión
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/pagos" target="">
#              Pagos
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/servicios-fiduciarios" target="">
#              Servicios fiduciarios
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/servicios-internacionales" target="">
#              Servicios internacionales
#             </a>
#            </li>
#            <li class="">
#             <a href="http://www.lafise.com/blb/banca-corporativa/servicio-de-afiliacion-a-pos" target="">
#              Servicio de afiliación a POS
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.lafise.com/blb/banca-corporativa/ecocreditos" target="">
#              ECOCréditos
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="">
#           <a href="http://fundacionzt.org/" target="">
#            RSE
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <section>
#     <div class="row clearfix">
#      <div class="clearfix">
#       <div class="grid_12 alpha omega bannerHome" id="dnn_bannerHome">
#        <div class="DnnModule DnnModule-EasyDNNGallery DnnModule-660">
#         <a name="660">
#         </a>
#         <div id="dnn_ctr660_ContentPane">
#          <!-- Start_Module_660 -->
#          <div class="DNNModuleContent ModEasyDNNGalleryC" id="dnn_ctr660_ModuleContent">
#           <script type="text/javascript">
#            if (typeof eds1_8 != 'undefined') {
# 		if ('eds1_8'=='jQuery')
# 			jQuery.noConflict();
# 		if('True' == "True")
# 		{
# 			eds1_8(document).ready(function ($) {
# 			var showtips = 'true';
# 				$('#M660EasyDNNGallery a[rel^="prettyPhoto"], #M660EasyDNNGallery a[rel^="slP"]').each(function () {
# 					if ($(this).attr("title")) {
# 						if ($(this).attr("title").length > 0) {
# 							$(this).attr("pptitle", $(this).attr("title"));
# 							if (showtips == 'false') {
# 								if ($(this).attr("title").length > 0) {
# 									$(this).attr("title", "");
# 								}
# 							}
# 						}
# 					}
# 				});
# 				if ("prettyphoto" == "prettyphoto") {
# 					$('#M660EasyDNNGallery a[rel^="prettyPhoto"], a[rel^="slP"]').prettyPhoto({
# 							animationSpeed: 'default',
# 							slideshow: false,
# 							autoplay_slideshow: false,
# 							padding: 40,
# 							opacity: 0.8,
# 							showTitle: true,
# 							allowresize: true,
# 							hideflash: true,
# 							downloadText:'Download image',
# 							wmode: 'opaque',
# 							autoplay: false,
# 							modal: false,
# 							overlay_gallery: false,
# 							counter_separator_label: '/',
# 							print_image_text: 'Print image',
# 							item_emailing_text: 'Email the link',
# 							item_emailing_subject: 'Take a look at this image',
# 							allow_image_printing:false,
# 							enable_item_emailing:false,
# 							show_social_sharing:false,
# 							download_handler_url:'false',
# 							theme: 'pp_default',
# 							callback: function() { }
# 						});
# 				}
# 			});
# 		}
# 	}
#           </script>
#           <div class="eds_galleryWrapper" id="M660EasyDNNGallery">
#            <style type="text/css">
#             #M660
# 	{
# 		background:#202834 url(/DesktopModules/EasyDnnGallery/css/images/loading.gif) no-repeat scroll 50% 50%;
#
# 		position:relative;
# 	}
# 	#M660 img
# 	{
# 		display:none;
# 		left:0;
# 		position:absolute;
# 		top:0;
# 	}
# 	#M660 a
# 	{
# 		border:0 none;
# 		display:block;
# 	}
# 	.eds_edn_qtip2_style
# 	{
# 		-moz-border-radius: 5px;
# 		-webkit-border-radius: 5px;
# 		border-radius: 5px;
# 		border-width: 5px;
# 	}
#            </style>
#            <div id="dnn_ctr660_ViewEasyDNNGallery_ctl00_ImageSliderOne">
#             <script type="text/javascript">
#              eds1_8(document).ready(function($)
# {
# 	$('#M660').nivoSlider({
# 		effect:'fade',
# 		animSpeed:500,
# 		pauseTime:5000,
# 		startSlide:0,
# 		directionNav:true,
# 		directionNavHide:true,
# 		controlNav:true,
# 		controlNavThumbs:false,
# 		controlNavThumbsFromRel:false,
# 		keyboardNav:true,
# 		pauseOnHover:true,
# 		manualAdvance:false,
# 		captionOpacity:0.8
# 	});
# 	if('true'=='true') {
# 	if('false'=='true') {
# 				$('#M660 a, #M660EasyDNNGallery .EDGvideo a[title], #M660EasyDNNGallery .EDGaudio a[title]').qtip({
# 					show: {  effect: function(offset) { $(this).fadeIn(500); } },
# 					hide: {  effect: function(offset) { $(this).fadeOut(500); } },
# 					position: { at: 'topMiddle', my: 'bottomMiddle'},
# 					style: { classes: 'qtip-cream eds_edn_qtip2_style', tip: {corner: true, width: 10, height: 5}}
# 		});
# 		}
# 	}
# });
#             </script>
#             <div class="">
#              <div class="slider-wrapper theme-default" style="width: 100%; height: auto;margin: 0 auto ;">
#               <div id="M660" style="width: 100%; height: auto;">
#                <a edgpid="286" href="/Portals/1/EasyGalleryImages/3/5/bannerfinal.jpg" rel="" target="_self" title="">
#                 <img id="dnn_ctr660_ViewEasyDNNGallery_ctl00_repImageSlider_imgImageSlider_0" src="/Portals/1/EasyGalleryImages/660/ImageSlider/Thumbs/bannerfinal.jpg" title=""/>
#                </a>
#                <a edgpid="543" href="/Portals/1/EasyGalleryImages/3/5/ahorro_programado.jpg" rel="" target="_self" title="">
#                 <img id="dnn_ctr660_ViewEasyDNNGallery_ctl00_repImageSlider_imgImageSlider_1" src="/Portals/1/EasyGalleryImages/660/ImageSlider/Thumbs/ahorro_programado.jpg" title=""/>
#                </a>
#                <a edgpid="283" href="/Portals/1/EasyGalleryImages/3/5/excelentelugar.jpg" rel="" target="_self" title="">
#                 <img id="dnn_ctr660_ViewEasyDNNGallery_ctl00_repImageSlider_imgImageSlider_2" src="/Portals/1/EasyGalleryImages/660/ImageSlider/Thumbs/excelentelugar.jpg" title=""/>
#                </a>
#                <a edgpid="548" href="https://www.lafise.com/blb/banca-personal/canales-electr%C3%B3nicos/transferencias-interbancarias-v%C3%ADa-ach" rel="" target="_self" title="">
#                 <img id="dnn_ctr660_ViewEasyDNNGallery_ctl00_repImageSlider_imgImageSlider_3" src="/Portals/1/EasyGalleryImages/660/ImageSlider/Thumbs/Adaptaciones ACH_Banner Web.jpg" title=""/>
#                </a>
#               </div>
#              </div>
#             </div>
#             <div style="clear: left">
#             </div>
#            </div>
#           </div>
#           <div>
#           </div>
#          </div>
#          <!-- End_Module_660 -->
#         </div>
#        </div>
#       </div>
#       <div class="grid_12 alpha omega bannerHome responsive" id="dnn_bannerHomeResponsive">
#        <div class="DnnModule DnnModule-EasyDNNGallery DnnModule-681">
#         <a name="681">
#         </a>
#         <div id="dnn_ctr681_ContentPane">
#          <!-- Start_Module_681 -->
#          <div class="DNNModuleContent ModEasyDNNGalleryC" id="dnn_ctr681_ModuleContent">
#           <script type="text/javascript">
#            if (typeof eds1_8 != 'undefined') {
# 		if ('eds1_8'=='jQuery')
# 			jQuery.noConflict();
# 		if('True' == "True")
# 		{
# 			eds1_8(document).ready(function ($) {
# 			var showtips = 'true';
# 				$('#M681EasyDNNGallery a[rel^="prettyPhoto"], #M681EasyDNNGallery a[rel^="slP"]').each(function () {
# 					if ($(this).attr("title")) {
# 						if ($(this).attr("title").length > 0) {
# 							$(this).attr("pptitle", $(this).attr("title"));
# 							if (showtips == 'false') {
# 								if ($(this).attr("title").length > 0) {
# 									$(this).attr("title", "");
# 								}
# 							}
# 						}
# 					}
# 				});
# 				if ("prettyphoto" == "prettyphoto") {
# 					$('#M681EasyDNNGallery a[rel^="prettyPhoto"], a[rel^="slP"]').prettyPhoto({
# 							animationSpeed: 'default',
# 							slideshow: false,
# 							autoplay_slideshow: false,
# 							padding: 40,
# 							opacity: 0.8,
# 							showTitle: true,
# 							allowresize: true,
# 							hideflash: true,
# 							downloadText:'Download image',
# 							wmode: 'opaque',
# 							autoplay: false,
# 							modal: false,
# 							overlay_gallery: false,
# 							counter_separator_label: '/',
# 							print_image_text: 'Print image',
# 							item_emailing_text: 'Email the link',
# 							item_emailing_subject: 'Take a look at this image',
# 							allow_image_printing:false,
# 							enable_item_emailing:false,
# 							show_social_sharing:false,
# 							download_handler_url:'false',
# 							theme: 'pp_default',
# 							callback: function() { }
# 						});
# 				}
# 			});
# 		}
# 	}
#           </script>
#           <div class="eds_galleryWrapper" id="M681EasyDNNGallery">
#            <style type="text/css">
#             #M681
# 	{
# 		background:#202834 url(/DesktopModules/EasyDnnGallery/css/images/loading.gif) no-repeat scroll 50% 50%;
#
# 		position:relative;
# 	}
# 	#M681 img
# 	{
# 		display:none;
# 		left:0;
# 		position:absolute;
# 		top:0;
# 	}
# 	#M681 a
# 	{
# 		border:0 none;
# 		display:block;
# 	}
# 	.eds_edn_qtip2_style
# 	{
# 		-moz-border-radius: 5px;
# 		-webkit-border-radius: 5px;
# 		border-radius: 5px;
# 		border-width: 5px;
# 	}
#            </style>
#            <div id="dnn_ctr681_ViewEasyDNNGallery_ctl00_ImageSliderOne">
#             <script type="text/javascript">
#              eds1_8(document).ready(function($)
# {
# 	$('#M681').nivoSlider({
# 		effect:'fade',
# 		animSpeed:500,
# 		pauseTime:5000,
# 		startSlide:0,
# 		directionNav:true,
# 		directionNavHide:true,
# 		controlNav:true,
# 		controlNavThumbs:false,
# 		controlNavThumbsFromRel:false,
# 		keyboardNav:true,
# 		pauseOnHover:true,
# 		manualAdvance:false,
# 		captionOpacity:0.8
# 	});
# 	if('true'=='true') {
# 	if('false'=='true') {
# 				$('#M681 a, #M681EasyDNNGallery .EDGvideo a[title], #M681EasyDNNGallery .EDGaudio a[title]').qtip({
# 					show: {  effect: function(offset) { $(this).fadeIn(500); } },
# 					hide: {  effect: function(offset) { $(this).fadeOut(500); } },
# 					position: { at: 'topMiddle', my: 'bottomMiddle'},
# 					style: { classes: 'qtip-cream eds_edn_qtip2_style', tip: {corner: true, width: 10, height: 5}}
# 		});
# 		}
# 	}
# });
#             </script>
#             <div class="">
#              <div class="slider-wrapper theme-default" style="width: 100%; height: auto;margin: 0 auto ;">
#               <div id="M681" style="width: 100%; height: auto;">
#                <a edgpid="389" href="/Portals/1/EasyGalleryImages/6/12/bannermobile1.jpg" rel="" target="_self" title="">
#                 <img id="dnn_ctr681_ViewEasyDNNGallery_ctl00_repImageSlider_imgImageSlider_0" src="/Portals/1/EasyGalleryImages/681/ImageSlider/Thumbs/bannermobile1.jpg" title=""/>
#                </a>
#                <a edgpid="290" href="/Portals/1/EasyGalleryImages/6/12/excelentelugarresponsive1.jpg" rel="" target="_self" title="">
#                 <img id="dnn_ctr681_ViewEasyDNNGallery_ctl00_repImageSlider_imgImageSlider_1" src="/Portals/1/EasyGalleryImages/681/ImageSlider/Thumbs/excelentelugarresponsive1.jpg" title=""/>
#                </a>
#                <a edgpid="546" href="/Portals/1/EasyGalleryImages/6/12/banner_calculadora_banner.jpg" rel="" target="_self" title="">
#                 <img id="dnn_ctr681_ViewEasyDNNGallery_ctl00_repImageSlider_imgImageSlider_2" src="/Portals/1/EasyGalleryImages/681/ImageSlider/Thumbs/banner_calculadora_banner.jpg" title=""/>
#                </a>
#                <a edgpid="547" href="https://www.lafise.com/blb/banca-personal/canales-electr%C3%B3nicos/transferencias-interbancarias-v%C3%ADa-ach" rel="" target="_self" title="">
#                 <img id="dnn_ctr681_ViewEasyDNNGallery_ctl00_repImageSlider_imgImageSlider_3" src="/Portals/1/EasyGalleryImages/681/ImageSlider/Thumbs/Adaptaciones ACH_LAFISE MOVIL.jpg" title=""/>
#                </a>
#               </div>
#              </div>
#             </div>
#             <div style="clear: left">
#             </div>
#            </div>
#           </div>
#           <div>
#           </div>
#          </div>
#          <!-- End_Module_681 -->
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <section>
#     <div class="row clearfix carrusel">
#      <div class="container clearfix">
#       <div class="ax-tab-container">
#        <div class="ax-carousel">
#         <div class="ax-selected">
#         </div>
#         <ul class="ax-tabs">
#          <li>
#           <a class="ax-icon-1" data-tab="1" href="javascript:void(0);">
#            Tarjetas de crédito
#           </a>
#          </li>
#          <li class="ax-active">
#           <a class="ax-icon-2" data-tab="2" href="javascript:void(0);">
#            Préstamos personales
#           </a>
#          </li>
#          <li>
#           <a class="ax-icon-3" data-tab="3" href="javascript:void(0);">
#            Préstamos hipotecarios
#           </a>
#          </li>
#          <li>
#           <a class="ax-icon-4" data-tab="4" href="javascript:void(0);">
#            Ahorro
#           </a>
#          </li>
#          <li>
#           <a class="ax-icon-5" data-tab="5" href="javascript:void(0);">
#            Inversión
#           </a>
#          </li>
#         </ul>
#        </div>
#        <a class="ax-prev" href="javascript:void(0);">
#         Anterior
#        </a>
#        <a class="ax-next" href="javascript:void(0);">
#         Siguiente
#        </a>
#        <div class="ax-tab-content">
#         <div class="ax-tab" data-tab="1">
#          <div id="dnn_carruselTab1">
#           <div class="DnnModule DnnModule-DNN_HTML DnnModule-4724 DnnVersionableControl">
#            <a name="4724">
#            </a>
#            <div class="DNNContainer_noTitle">
#             <div id="dnn_ctr4724_ContentPane">
#              <!-- Start_Module_4724 -->
#              <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr4724_ModuleContent">
#               <div id="dnn_ctr4724_HtmlModule_lblContent">
#                <div class="grid_6 alpha omega">
#                 <p>
#                  <img alt="Tarjeta de crédito" src="/portals/1/Images/home/tarjeta-credito.jpg?ver=2016-05-04-122655-353" style="max-width: 100%" title="Tarjeta de Crédito"/>
#                 </p>
#                </div>
#                <div class="grid_6">
#                 <h2>
#                  Tarjetas de Crédito
#                 </h2>
#                 <p>
#                  <strong>
#                   Banco LAFISE BANCENTRO
#                  </strong>
#                  le permite llevar con usted el mundo en sus manos, con las ventajas que le ofrecen nuestras Tarjetas.
#                 </p>
#                 <p>
#                  Conoce el programa de
#                  <strong>
#                   Puntos LAFISE
#                  </strong>
#                  y otros beneficios otorgados al obtener tu Tarjeta de Crédito.
#                 </p>
#                 <p>
#                  <a class="btn" href="/blb/banca-personal/tarjetas/tarjetas-credito/solicitud-tarjeta-credito">
#                   Solicitar aquí
#                  </a>
#                 </p>
#                </div>
#               </div>
#              </div>
#              <!-- End_Module_4724 -->
#             </div>
#             <div class="clear">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="ax-tab" data-tab="2">
#          <div id="dnn_carruselTab2">
#           <div class="DnnModule DnnModule-DNN_HTML DnnModule-4723 DnnVersionableControl">
#            <a name="4723">
#            </a>
#            <div class="DNNContainer_noTitle">
#             <div id="dnn_ctr4723_ContentPane">
#              <!-- Start_Module_4723 -->
#              <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr4723_ModuleContent">
#               <div id="dnn_ctr4723_HtmlModule_lblContent">
#                <div class="grid_6 alpha omega">
#                 <img alt="Préstamos" src="/portals/1/Images/home/creditos_personales.jpg?ver=2016-05-17-162547-100" style="max-width: 100%" title="Préstamos personales"/>
#                </div>
#                <div class="grid_6">
#                 <h2>
#                  Préstamos Personales
#                 </h2>
#                 <p>
#                  Contamos con los mejores planes de financiamiento para que alcances tus metas y hagas tus proyectos realidad.
#                 </p>
#                 <p>
#                  Remodela tu casa, continúa con tus estudios o realiza viajes con este ágil e innovador producto.
#                 </p>
#                 <p>
#                  <a class="btn" href="/blb/banca-personal/prestamos/solicitud-prestamos-personales">
#                   Solicitar aquí
#                  </a>
#                 </p>
#                </div>
#               </div>
#              </div>
#              <!-- End_Module_4723 -->
#             </div>
#             <div class="clear">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="ax-tab" data-tab="3">
#          <div id="dnn_carruselTab3">
#           <div class="DnnModule DnnModule-DNN_HTML DnnModule-4725 DnnVersionableControl">
#            <a name="4725">
#            </a>
#            <div class="DNNContainer_noTitle">
#             <div id="dnn_ctr4725_ContentPane">
#              <!-- Start_Module_4725 -->
#              <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr4725_ModuleContent">
#               <div id="dnn_ctr4725_HtmlModule_lblContent">
#                <div class="grid_6 alpha omega">
#                 <img alt="prestamo vivienda" src="/portals/1/Images/home/prestamo-hipotecario.jpg?ver=2016-05-13-124713-477" style="max-width: 100%" title="Préstamo hipotecarios"/>
#                </div>
#                <div class="grid_6">
#                 <h2>
#                  Préstamos Hipotecarios
#                 </h2>
#                 <p>
#                  Con
#                  <strong>
#                   Banco LAFISE BANCENTR
#                  </strong>
# ...
#                 <img alt="CON MODERNA SUCURSAL EN GALERÍA SANTO DOMINGO" src="/Portals/1/EasyDNNNews/175/12001200p664EDNthumbsuc_galerias.jpg"/>
#                </a>
#               </div>
#               <div class="contenido">
#                <h2>
#                 <a href="https://www.lafise.com/blb/noticias/con-moderna-sucursal-en-galer205a-santo-domingo" target="_self">
#                  CON MODERNA SUCURSAL EN GALERÍA SANTO DOMINGO
#                 </a>
#                </h2>
#                <div class="entradilla">
#                 Banco LAFISE BANCENTRO comprometido en brindar atención de calidad y excelente servicio  a sus clientes y público en general...
#                </div>
#                <a class="button" href="https://www.lafise.com/blb/noticias/con-moderna-sucursal-en-galer205a-santo-domingo" target="_self">
#                 Ver más
#                </a>
#               </div>
#              </div>
#              <!--ArticleTemplate-->
#              <div class="articulo">
#               <div class="imagen">
#                <a class="article_image" href="https://www.lafise.com/blb/noticias/asesorando-siempre-a-sus-clientes" target="_self">
#                 <img alt="ASESORANDO SIEMPRE A SUS CLIENTES" src="/Portals/1/EasyDNNNews/174/12001200p664EDNthumbzona_central.jpg"/>
#                </a>
#               </div>
#               <div class="contenido">
#                <h2>
#                 <a href="https://www.lafise.com/blb/noticias/asesorando-siempre-a-sus-clientes" target="_self">
#                  ASESORANDO SIEMPRE A SUS CLIENTES
#                 </a>
#                </h2>
#                <div class="entradilla">
#                 Sobre el entorno internacional que vive el sector productivo nicaragüense como los cambiantes precios en el mercado internacional, el cambio...
#                </div>
#                <a class="button" href="https://www.lafise.com/blb/noticias/asesorando-siempre-a-sus-clientes" target="_self">
#                 Ver más
#                </a>
#               </div>
#              </div>
#             </div>
#             <!--ArticleRepeat:After:-->
#            </div>
#           </div>
#          </div>
#          <!-- End_Module_664 -->
#         </div>
#        </div>
#        <div class="DnnModule DnnModule-DNN_HTML DnnModule-2483 DnnVersionableControl">
#         <a name="2483">
#         </a>
#         <div id="dnn_ctr2483_ContentPane">
#          <!-- Start_Module_2483 -->
#          <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr2483_ModuleContent">
#           <div id="dnn_ctr2483_HtmlModule_lblContent">
#            <div class="contentButton">
#             <a class="btn" href="/blb/novedades-lafise/">
#              Ver más noticias
#             </a>
#            </div>
#           </div>
#          </div>
#          <!-- End_Module_2483 -->
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <section>
#     <div class="row grayBg clearfix">
#      <div class="container clearfix">
#       <div class="grid_12 newsletters" id="dnn_newsletters">
#        <div class="DnnModule DnnModule-DNN_HTML DnnModule-4834 DnnVersionableControl">
#         <a name="4834">
#         </a>
#         <div id="dnn_ctr4834_ContentPane">
#          <!-- Start_Module_4834 -->
#          <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr4834_ModuleContent">
#           <div id="dnn_ctr4834_HtmlModule_lblContent">
#            <span class="tittleNewsletters">
#             Suscripción a boletines
#            </span>
#           </div>
#          </div>
#          <!-- End_Module_4834 -->
#         </div>
#        </div>
#        <div class="DnnModule DnnModule-FrontEndSuscripcionBoletin DnnModule-4833">
#         <a name="4833">
#         </a>
#         <div class="tabsProC dnnsharp-container" style="padding: 4px; overflow: visible;">
#          <div class="tp-module-header">
#           <span class=" " id="dnn_ctr4833_dnnTITLE_titleLabel">
#            Suscripcion Boletin
#           </span>
#          </div>
#          <div id="dnn_ctr4833_ContentPane" style="margin: 10px;">
#           <!-- Start_Module_4833 -->
#           <div class="DNNModuleContent ModFrontEndSuscripcionBoletinC" id="dnn_ctr4833_ModuleContent">
#            <link href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" rel="stylesheet"/>
#            <link href="/App/Base/css/grid.css" rel="stylesheet"/>
#            <div class="lafise-container" id="suscripcionBoletinModule">
#             <div data-ng-controller="SuscripcionBoletinController">
#              <div class="lafise-group">
#               <ng-form name="addSuscripcion" ng-submit="add()">
#                <!-- Crear suscripción a boletin -->
#                <div class="lafise-container-suscripcion-boletin">
#                 <!-- Etiqueta Suscripción a boletines -->
#                 <div class="lafise-group">
#                  <!-- Nombre  -->
#                  <div class="lafise-group">
#                   <div class="lafise-container-text">
#                    <input class="lafise-text" data-ng-class="{submitted:addSuscripcion.submitted}" data-ng-model="newSuscripcion.Nombre" maxlength="100" name="nombre" placeholder="NOMBRES" required="" type="text"/>
#                   </div>
#                  </div>
#                  <!-- Email -->
#                  <div class="lafise-group">
#                   <div class="lafise-container-text">
#                    <input class="lafise-text" data-ng-blur="FormatoEmail()" data-ng-class="{submitted:addSuscripcion.submitted}" data-ng-focus="closeAlert($index)" data-ng-model="newSuscripcion.Email" id="correo" maxlength="200" name="correo" placeholder="CORREO ELECTRÓNICO" required="" type="email"/>
#                   </div>
#                  </div>
#                  <!-- Alerta - Email inválido -->
#                  <div data-ng-class="'alert alert-danger alert-dismissible'" data-ng-show="showMsgEmail" id="validacionEmail" role="alert">
#                   <button aria-label="Close" class="close" data-dismiss="alert" data-ng-click="hideValidacion()" type="button">
#                    <span aria-hidden="true">
#                     ×
#                    </span>
#                   </button>
#                   <span data-ng-bind="msgValidarCorreo">
#                   </span>
#                  </div>
#                  <!--Acepta ley de tratamiento y uso de datos LAFISE-->
#                  <div class="lafise-group contentCheck">
#                   <div class="lafise-container-check">
#                    <input data-ng-model="newSuscripcion.AceptoLey" name="aceptoLey" type="checkbox"/>
#                    Acepto términos y condiciones de LAFISE
#                   </div>
#                  </div>
#                 </div>
#                 <!-- Boton Suscribirme -->
#                 <div class="lafise-container-options">
#                  <div class="lafise-group">
#                   <input class="lafise-button" data-ng-click="submitted=true;add()" type="button" value="Suscribirme"/>
#                  </div>
#                 </div>
#                </div>
#               </ng-form>
#              </div>
#              <div class="loading-spiner-holder" data-loading="">
#               <div class="loading-spiner">
#                <img src="/images/ajax-loader.gif"/>
#                Cargando
#               </div>
#              </div>
#              <!-- Alerta -->
#              <uib-alert close="closeAlert($index)" dismiss-on-timeout="5000" ng-bind="alert.msg" ng-repeat="alert in alerts" ng-show="showMsg" type="{{::alert.type}}">
#              </uib-alert>
#             </div>
#            </div>
#            <!--CDF(Javascript|/App/Base/js/angular.min.js?cdv=100)-->
#            <!--CDF(Javascript|/App/Base/js/ui-bootstrap-tpls.min.js?cdv=100)-->
#            <!--CDF(Javascript|/App/FrontEnd/SuscripcionBoletin/SuscripcionBoletinModule.js?cdv=100)-->
#            <!--CDF(Javascript|/App/FrontEnd/SuscripcionBoletin/SuscripcionBoletinFactory.js?cdv=100)-->
#            <!--CDF(Javascript|/App/FrontEnd/SuscripcionBoletin/SuscripcionBoletinController.js?cdv=100)-->
#            <!--CDF(Javascript|/App/Base/js/VentanaCargando.js?cdv=100)-->
#           </div>
#           <!-- End_Module_4833 -->
#          </div>
#          <div style="float: right;">
#          </div>
#          <div style="clear:both;">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <footer>
#     <div class="row footer clearfix">
#      <div class="container clearfix">
#       <div class="grid_3 col-1" id="dnn_col_1">
#        <div class="DnnModule DnnModule-DNN_HTML DnnModule-656 DnnVersionableControl">
#         <a name="656">
#         </a>
#         <div id="dnn_ctr656_ContentPane">
#          <!-- Start_Module_656 -->
#          <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr656_ModuleContent">
#           <div id="dnn_ctr656_HtmlModule_lblContent">
#            <p>
#             <a href="/">
#             </a>
#            </p>
#            <a href="/">
#             <img alt="" src="/portals/0/Images/logoFooter.jpg"/>
#            </a>
#            <p>
#             Copyright 2016
#            </p>
#            <br/>
#            <p>
#             <strong style="font-family: Arial, Helvetica, Verdana, Tahoma, sans-serif; background-color: initial;">
#              Banco LAFISE Bancentro
#             </strong>
#            </p>
#            <p>
#             es miembro del:
#            </p>
#            <img src="/portals/1/Images/Banca/fogade.jpg"/>
#           </div>
#          </div>
#          <!-- End_Module_656 -->
#         </div>
#        </div>
#       </div>
#       <div class="grid_5 col-3" id="dnn_col_2">
#        <div class="DnnModule DnnModule-DNN_HTML DnnModule-657 DnnVersionableControl">
#         <a name="657">
#         </a>
#         <div id="dnn_ctr657_ContentPane">
#          <!-- Start_Module_657 -->
#          <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr657_ModuleContent">
#           <div id="dnn_ctr657_HtmlModule_lblContent">
#            <p>
#             <span>
#              Acerca de LAFISE
#             </span>
#            </p>
#            <ul>
#             <li>
#              <a href="/blb/acerca-de-lafise/nuestros-valores">
#               Nuestros valores
#              </a>
#             </li>
#             <li>
#              <a href="/blb/acerca-de-lafise/junta-directiva-y-mensaje-de-nuestro-presidente">
#               Junta directiva y mensaje de nuestro presidente
#              </a>
#             </li>
#             <li>
#              <a href="/blb/acerca-de-lafise/principales-ejecutivos-y-mensaje-de-nuestro-gerente-general">
#               Principales ejecutivos
#              </a>
#             </li>
#             <li>
#              <a href="http://fundacionzt.org/" target="_blank">
#               Responsabilidad social empresarial
#              </a>
#             </li>
#             <li>
#              <a href="/blb/acerca-de-lafise/estados-financieros">
#               Estados financieros
#              </a>
#             </li>
#             <li>
#              <a href="https://capitalhumano.lafise.com/rysPublico" target="_blank">
#               Trabaja con nosotros
#              </a>
#              .
#             </li>
#            </ul>
#           </div>
#          </div>
#          <!-- End_Module_657 -->
#         </div>
#        </div>
#       </div>
#       <div class="grid_2 col-4" id="dnn_col_3">
#        <div class="DnnModule DnnModule-DNN_HTML DnnModule-658 DnnVersionableControl">
#         <a name="658">
#         </a>
#         <div id="dnn_ctr658_ContentPane">
#          <!-- Start_Module_658 -->
#          <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr658_ModuleContent">
#           <div id="dnn_ctr658_HtmlModule_lblContent">
#            <p>
#             <span>
#              Monibyte
#             </span>
#            </p>
#            <ul>
#             <li>
#              <a href="/blb/banca-corporativa/monibyte">
#               Monibyte
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <!-- End_Module_658 -->
#         </div>
#        </div>
#       </div>
#       <div class="grid_2 col-5" id="dnn_col_4">
#        <div class="DnnModule DnnModule-DNN_HTML DnnModule-659 DnnVersionableControl">
#         <a name="659">
#         </a>
#         <div id="dnn_ctr659_ContentPane">
#          <!-- Start_Module_659 -->
#          <div class="DNNModuleContent ModDNNHTMLC" id="dnn_ctr659_ModuleContent">
#           <div id="dnn_ctr659_HtmlModule_lblContent">
#            <ul>
#             <li>
#              <a href="/terminos-y-condiciones-de-uso">
#               Términos y condiciones
#              </a>
#             </li>
#            </ul>
#            <a class="reclamo" href="/blb/contactenos">
#             Quejas y sugerencias
#            </a>
#           </div>
#          </div>
#          <!-- End_Module_659 -->
#         </div>
#        </div>
#       </div>
#       <div class="toTop" id="toTop">
#        <img src="/Portals/1/Skins/banca/images/footer/toTop.jpg"/>
#       </div>
#      </div>
#     </div>
#    </footer>
#    <div class="ContentPane DNNEmptyPane" id="dnn_ContentPane">
#    </div>
#    <div class="chatContainer">
#     <div class="chatContent DNNEmptyPane" id="dnn_chatContent">
#     </div>
#    </div>
#    <!--Styles-->
#    <link href="/portals/1/skins/banca/css/grid.css" rel="stylesheet" type="text/css"/>
#    <link href="/portals/1/skins/banca/css/styles.css" rel="stylesheet" type="text/css"/>
#    <link href="/portals/1/skins/banca/css/responsive.css" rel="stylesheet" type="text/css"/>
#    <link href="https://fonts.googleapis.com/css?family=Montserrat:400,700|Lato:400,300,700" rel="stylesheet" type="text/css"/>
#    <!-- JS -->
#    <script src="/Portals/0/skins/institucional/js/scripts.js" type="text/javascript">
#    </script>
#    <!-- /JS -->
#    <!-- Start of LiveChat (www.livechatinc.com) code -->
#    <script type="text/javascript">
#     window.__lc = window.__lc || {};
# 	window.__lc.license = 7182821;
# 	(function() {
# 	  var lc = document.createElement('script'); lc.type = 'text/javascript'; lc.async = true;
# 	  lc.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdn.livechatinc.com/tracking.js';
# 	  var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(lc, s);
# 	})();
#    </script>
#    <!-- End of LiveChat code -->
#    <input id="ScrollTop" name="ScrollTop" type="hidden"/>
#    <input autocomplete="off" id="__dnnVariable" name="__dnnVariable" type="hidden" value="`{`__scdoff`:`1`,`sf_siteRoot`:`/blb/`,`sf_tabId`:`131`,`evoq_TabId`:`131`,`evoq_PageLanguage`:`en-US`,`evoq_ContentItemId`:`-1`,`evoq_UrlReferrer`:``,`evoq_UrlPath`:`https%3a%2f%2fwww.lafise.com%2fblb%2f`,`evoq_UrlQuery`:`%3fTabId%3d131%26language%3den-US`,`evoq_ContentItemReferrer`:`-1`,`evoq_PersonalizedUrlReferrer`:`-1`,`evoq_DisableAnalytics`:`False`}"/>
#    <input name="__RequestVerificationToken" type="hidden" value="by8XK30Cs3HAXyk7jR2P5RapqhDaOAqK0rlMo2uodCUMtsoJgaE-gfUBtE7oj1DGe569Bf-Y6jyNrvnebVqAUBYvoeqXWu-D9dn3kz0azCSGw3qYldkkTyxsu2w1"/>
#    <script type="text/javascript">
#     //<![CDATA[
# (function() {
#
#   var analyticsSettings;
#   var initAnalyticsSettings = function (e) {
#     analyticsSettings = {
#       pageStart: analytics_page_startTime,
#       servicesFramework: $.ServicesFramework(-1)
#     };
#   };
#   if(window.addEventListener) {
#     window.addEventListener('load', initAnalyticsSettings, false);
#   } else {
#     window.attachEvent('onload', initAnalyticsSettings);
#   };
#
#   var eventName = (window.onpagehide || window.onpagehide === null) ? 'pagehide' : 'unload';
#   if (window.addEventListener) {
#     window.addEventListener(eventName, function (e) {
#       if (analyticsSettings) {
#         analyticsSettings.eventSource = 'pagehide';
#         if(dnn && dnn.analytics) { dnn.analytics.clientUnloading(e,analyticsSettings); }
#       }
#     }, false);
#   } else {
#     window.attachEvent('on' + eventName, function (e) {
#       if (analyticsSettings) {
#         analyticsSettings.eventSource = 'pagehide';
#         if(dnn && dnn.analytics) { dnn.analytics.clientUnloading(e,analyticsSettings); }
#       }
#     });
#   }
#
# })();
# //]]>
#    </script>
#    <script src="/Resources/Shared/scripts/initWidgets.js" type="text/javascript">
#    </script>
#   </form>
#  </body>
# </html>

# %%
def _get_soup_object(url, parser="html.parser"):
    return BeautifulSoup(requests.get(url).text, parser)

# %%
from bs4 import BeautifulSoup
import urllib
headers = {'User-agent': 'Mozilla/5.0'}
r = urllib.urlopen('https://www.lafise.com/blb/', headers=headers)
soup = BeautifulSoup(r, 'html.parser')
print type(soup)
print soup.prettify()[0:1000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-505f0935e02f> in <module>()
#       2 import urllib
#       3 headers = {'User-agent': 'Mozilla/5.0'}
# ----> 4 r = urllib.urlopen('https://www.lafise.com/blb/', headers=headers)
#       5 soup = BeautifulSoup(r, 'html.parser')
#       6 print type(soup)
#
# TypeError: urlopen() got an unexpected keyword argument 'headers'

# %%
tree2.xpath('//a/text()')
# Out:
# ['Register',
#  'Login',
#  'facebook',
#  'twitter',
#  'youtube',
#  'LinkedIn',
#  'Preguntas frecuentes',
#  u'Cont\xe1ctanos',
#  u'Encu\xe9ntranos',
#  'BancaNet',
#  'Nicaragua',
#  'Regional',
#  u'Men\xfa',
#  'Banca personal',
#  'Cuentas de ahorro',
#  'Cuenta corriente',
#  u'Pr\xe9stamos',
#  u'Pr\xe9stamos personales',
#  u'Pr\xe9stamos de veh\xedculos',
#  u'Solicitud pr\xe9stamos de veh\xcdculos',
#  'Calculadora',
#  u'Pr\xe9stamos de vivienda',
#  u'Solicitud pr\xe9stamos vivienda',
#  u'Pr\xe9stamos educativo',
#  'Tarjetas',
#  'Beneficios',
#  'Puntos LAFISE',
#  'LAFISE Plus',
#  'Extrafinanciamientos',
#  'Plan de Compras en Cuotas',
#  u'Tasa 0 (0% inter\xe9s)',
#  u'Tarjetas cr\xe9dito',
#  'Tarjeta Infinite Visa',
#  'Tarjeta Signature Visa',
#  'Tarjeta Platinum Visa',
#  'Tarjeta Dorada Visa',
#  u'Tarjeta Cl\xe1sica Visa',
#  u'Tarjeta Fundaci\xf3n Zamora Teran Visa',
#  'Tarjeta DTodo Visa',
#  'Tarjeta Business Visa',
#  'Tarjeta Platinum  Mastercard',
#  'Tarjeta Dorada Mastercard',
#  u'Tarjeta Cl\xe1sica Mastercard',
#  u'Solicitud Tarjeta Cr\xe9dito',
#  u'Tarjetas d\xe9bito',
#  u'Solicitud tarjeta d\xe9bito',
#  'Tarjetas prepago',
#  'Tarjeta Nomina Visa',
#  'Tarjeta Joven Visa',
#  'Servicios',
#  'Estado de cuenta por E-mail',
#  'Consultas, retiros y pagos de tarjeta',
#  'Telepagos 1800-8472',
#  u'Gestiones en l\xednea',
#  'Seguros al viajar',
#  'Seguros PRF, vida y asistencia',
#  'Contratos y reglamentos',
#  'Servicios bancarios',
#  'Canales Alternos',
#  'Banc@Net',
#  'Red ATM',
#  u'Env\xedo Veloz',
#  u'Transferencias interbancarias v\xeda ACH',
#  u'LAFISE M\xf3vil',
#  'Pag@Net',
#  'LAFISEid',
#  'ServiRED',
#  'Transferencias',
#  u'Gu\xeda de C\xe1lculo de Inter\xe9s y Mantenimiento de Valor',
#  'Banca corporativa',
#  'Cuentas',
#  'Financiamiento',
#  'Monibyte',
#  'Custodia y transporte de valores',
#  u'Inversi\xf3n',
#  'Pagos',
#  'Servicios fiduciarios',
#  'Servicios internacionales',
#  'Canales Alternos',
#  u'Servicio de afiliaci\xf3n a POS',
#  u'ECOCr\xe9ditos',
#  'Banca empresarial',
#  'Cuentas',
#  'Financiamiento',
#  'Monibyte',
#  u'Inversi\xf3n',
#  'Pagos',
#  'Servicios fiduciarios',
#  'Servicios internacionales',
#  u'Servicio de afiliaci\xf3n a POS',
#  u'ECOCr\xe9ditos',
#  'RSE',
#  '\r\n\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t',
#  u'Tarjetas de cr\xe9dito',
#  u'Pr\xe9stamos personales',
#  u'Pr\xe9stamos hipotecarios',
#  'Ahorro',
#  u'Inversi\xf3n',
#  'Anterior',
#  'Siguiente',
#  u'Solicitar aqu\xed',
#  u'Solicitar aqu\xed',
#  u'Solicitar aqu\xed',
#  u'Solicitar aqu\xed',
#  u'Ver m\xe1s',
#  'Banca Persona',
#  'Banca Corporativa',
#  'Banca Empresarial',
#  u'Canales Electr\xf3nicos',
#  u'Ver m\xe1s',
#  u'Ver m\xe1s',
#  u'Ver m\xe1s',
#  '\r\n            \t',
#  '\r\n            ',
#  u'FUNDACI\xd3N TELET\xd3N ENTREGA RECONOCIMIENTOS A GRUPO LAFISE Y COLABORADORES',
#  u'Ver m\xe1s',
#  '\r\n            \t',
#  '\r\n            ',
#  u'CON MODERNA SUCURSAL EN GALER\xcdA SANTO DOMINGO',
#  u'Ver m\xe1s',
#  '\r\n            \t',
#  '\r\n            ',
#  'ASESORANDO SIEMPRE A SUS CLIENTES',
#  u'Ver m\xe1s',
#  u'Ver m\xe1s noticias',
#  'Nuestros valores',
#  'Junta directiva y mensaje de nuestro presidente',
#  'Principales ejecutivos',
#  'Responsabilidad social empresarial',
#  'Estados financieros',
#  'Trabaja con nosotros',
#  'Monibyte',
#  u'T\xe9rminos y condiciones',
#  'Quejas y sugerencias']
